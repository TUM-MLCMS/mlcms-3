# %%
# Imports.
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
# Logistic function
def logistic(r, x):
    return r * x * (1 - x)

# %%
# Graphical representation of the function.
x = np.linspace(0, 1)
fig, ax = plt.subplots(1, 1)
ax.plot(x, logistic(2, x))
ax.set_title('Logistic Function with r=2')
# Out:
# Text(0.5, 1.0, 'Logistic Function with r=2')

# %%
# Iterate the function for a given growth rate, and plot the results.
def logistic_equation_orbit(x0, r, iteration, ax=None):
    X = []
    T = []
    t = 0
    x = x0
    
    # Iterate the logistic equation, printing only after 'skip' steps.
    for i in range(iteration):
        X.append(x)
        T.append(t)
        t+=1
        x = logistic(r,x);
        
    ax.plot(T, X)
    ax.set_ylim(0, 1)
    ax.set_xlim(0, T[-1])
    ax.set_xlabel('Time')
    ax.set_ylabel('X')
    ax.set_title(f"Orbit for $r={r:.1f}, \, x_0={x0:.1f}$")

fig, axs = plt.subplots(5, 2, figsize=(12, 18), sharey=True)
plt.subplots_adjust(hspace=0.4)

# Varying from 0 to 2.
logistic_equation_orbit(0.1, 0.0, 100, ax=axs[0, 0])
logistic_equation_orbit(0.1, 0.5, 100, ax=axs[1, 0])
logistic_equation_orbit(0.1, 1.0, 100, ax=axs[2, 0])
logistic_equation_orbit(0.1, 1.5, 100, ax=axs[3, 0])
logistic_equation_orbit(0.1, 2.0, 100, ax=axs[4, 0])

# Varying from 2 to 4.
logistic_equation_orbit(0.1, 2.0, 100, ax=axs[0, 1])
logistic_equation_orbit(0.1, 2.5, 100, ax=axs[1, 1])
logistic_equation_orbit(0.1, 3.0, 100, ax=axs[2, 1])
logistic_equation_orbit(0.1, 3.5, 100, ax=axs[3, 1])
logistic_equation_orbit(0.1, 4.0, 100, ax=axs[4, 1])

# %%
def plot_system(r, x0, n, ax=None):
    # Plot the function and the
    # y=x diagonal line.
    t = np.linspace(0, 1)
    ax.plot(t, logistic(r, t), 'k', lw=2)
    ax.plot([0, 1], [0, 1], 'r', lw=2)

    # Recursively apply logistic function.
    x = x0
    for i in range(n):
        y = logistic(r, x)
        
        # Plot the two lines.
        ax.plot([x, x], [x, y], 'k', alpha=0.3, lw=1)
        ax.plot([x, y], [y, y], 'k', alpha=0.3, lw=1)
        
        # Plot the positions with increasing saturation.
        ax.plot([x], [y], 'ok', ms=10, color=((i + 1)/n,0,(i + 1)/n, 1), alpha=0.5)
        x = y

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1.1)
    ax.set_title(f"$r={r:.1f}, \, x_0={x0:.1f}$")

fig, axs = plt.subplots(4, 2, figsize=(12, 24), sharey=True)

plot_system(0.5, .2, 10, ax=axs[0, 0])
plot_system(1.0, .2, 10, ax=axs[1, 0])
plot_system(1.5, .2, 10, ax=axs[2, 0])
plot_system(2.0, .2, 10, ax=axs[3, 0])
plot_system(2.5, .2, 10, ax=axs[0, 1])
plot_system(3.0, .2, 10, ax=axs[1, 1])
plot_system(3.5, .2, 10, ax=axs[2, 1])
plot_system(4.0, .2, 10, ax=axs[3, 1])

# %%
n = 10000
r = np.linspace(0.1, 4.0, n)

# %%
iterations = 1000
last = 100

# %%
x = 1e-5 * np.ones(n)

# %%
lyapunov = np.zeros(n)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 12))
plt.subplots_adjust(hspace=0.4)

X = []

for i in range(iterations):
    x = logistic(r, x)
    
    # Compute the partial sum of the Lyapunov exponent.
    lyapunov += np.log(abs(r - 2 * r * x))
    
    # Display the bifurcation diagram.
    if i >= (iterations - last):
        ax1.plot(r, x, ',k', alpha=.1)
        
ax1.set_xlim(0, 4)
ax1.set_ylim(0, 1)
ax1.set_xlabel("Growth Rate")
ax1.set_ylabel("X")
ax1.set_title("Bifurcation Diagram\n")

# Display the Lyapunov exponent, horizontal line.
ax2.axhline(0, color='k', lw=.5, alpha=.5)

# Negative Lyapunov exponent.
ax2.plot(r[lyapunov < 0], lyapunov[lyapunov < 0] / iterations, '.k', alpha=.5, ms=.5)

# Positive Lyapunov exponent.
ax2.plot(r[lyapunov >= 0], lyapunov[lyapunov >= 0] / iterations, '.r', alpha=.5, ms=.5)

bifurcations = []
bifurcations_point = []

sign = 0
for i in range (0, lyapunov.size):
    temp = sign
    if(lyapunov[i]<0):
        sign = -1
    elif(lyapunov[i]>0):
        sign = +1
    if(temp != sign and temp != 0):
        bifurcations.append(r[i])

for i in range(0, 8, 2):
    print(f"Interval for bifurcation {int((i/2)+1)} is ({bifurcations[i]:.3f}, {bifurcations[i+1]:.3f})")
    bifurcations_point.append((bifurcations[i] + bifurcations[i+1])/2)

for i in range(len(bifurcations_point)):
    print(f"Approximate bifurcation point {int(i+1)} is {bifurcations_point[i]:.3f}")
    ax1.axvline(x=[bifurcations_point[i]], ls='--', lw=0.6, color='g')
    ax2.plot([bifurcations_point[i]], [0], 'ok', ms=10, color='g', alpha=0.5)
    
ax2.set_xlim(0, 4)
ax2.set_ylim(-2, 1)
ax2.set_xlabel("Growth Rate")
ax2.set_title("Lyapunov Exponent\n")
# Out:
# Interval for bifurcation 1 is (1.000, 1.015)
# Interval for bifurcation 2 is (2.996, 3.002)
# Interval for bifurcation 3 is (3.448, 3.450)
# Interval for bifurcation 4 is (3.543, 3.545)
# Approximate bifurcation point 1 is 1.007
# Approximate bifurcation point 2 is 2.999
# Approximate bifurcation point 3 is 3.449
# Approximate bifurcation point 4 is 3.544
# Text(0.5, 1.0, 'Lyapunov Exponent\n')

# %%
from scipy.spatial import distance

rho = 28.0
sigma = 10.0
beta = 8.0 / 3.0

simulations = []

def d(x1, y1, z1, x2, y2, z2):
    p1 = (x1, y1, z1)
    p2 = (x2, y2, z2)
    return distance.euclidean(p1, p2)

def f(state, t):
    global rho, sigma, beta
    x, y, z = state  # Unpack the state vector
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  # Derivatives

def lorenz(r = 28.0, 
           s = 10.0, 
           b = 8.0 / 3.0, 
           state0 = [10.0, 10.0, 10.0],
           t = np.arange(0.0, 1000, 0.01),
           ax = None,
           line_color = 'g',
           start_color = 'b',
           end_color = 'r',
           point_size = 5,
           append = True):

    global rho, sigma, beta, simulations
    
    rho = r
    sigma = s
    beta = b
    
    states = odeint(f, state0, t)
    if(append):
        simulations.append(states)
    
    ax.plot(states[:, 0], states[:, 1], states[:, 2], color=line_color, alpha=0.7)

    # Starting point.
    ax.plot([state0[0]], [state0[1]], [state0[2]], 'ok', ms=point_size, color=start_color, alpha=1)

    # Ending point.
    ax.plot([states[int(states.size/3 - 1)][0]],  
            [states[int(states.size/3 - 1)][1]], 
            [states[int(states.size/3 - 1)][2]],'ok', ms=point_size, color=end_color, alpha=1)

fig = plt.figure(figsize=(16, 8))

ax0 = fig.add_subplot(1, 2, 1, projection='3d')
lorenz(ax=ax0, t = np.arange(0.0, 1000, 0.01))

ax1 = fig.add_subplot(1, 2, 2, projection='3d')
lorenz(ax=ax1, t = np.arange(0.0, 1000, 0.01), state0 = [10.0 + 0.00000001, 10.0, 10.0])

dist = 0
iter = 0
while(dist <= 1):
    dist = d(simulations[0][iter][0],
             simulations[0][iter][1],
             simulations[0][iter][2],
             simulations[1][iter][0],
             simulations[1][iter][1],
             simulations[1][iter][2],)
    iter += 1

fig.suptitle(f"Distance becomes larger than 1 after {iter/(simulations[0].size/3):.4f} seconds.", size=18)
# Out:
# Text(0.5, 0.98, 'Distance becomes larger than 1 after 0.0226 seconds.')

# %%
fig = plt.figure(figsize=(32, 32))

ax = fig.add_subplot(1, 1, 1, projection='3d')
lorenz(ax=ax, 
       t = np.arange(0.0, 50, 0.01), 
       line_color='green',
       start_color='blue',
       end_color='green',
       point_size=20,
       append = False)
lorenz(ax=ax, 
       t = np.arange(0.0, 50, 0.01), 
       state0 = [10.0 + 0.00000001, 10.0, 10.0],
       line_color='red',
       start_color='blue',
       end_color='red',
       point_size=20,
       append = False)

fig.suptitle(f"Visualization of both simulations in the same plot.", size=42)
# Out:
# Text(0.5, 0.98, 'Visualization of both simulations in the same plot.')

# %%
fig = plt.figure(figsize=(16, 8))

ax2 = fig.add_subplot(1, 2, 1, projection='3d')
lorenz(ax=ax2, 
       state0 = [10.0, 10.0, 10.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = 0.5,
       append = False)
lorenz(ax=ax2, 
       state0 = [2.0, 8.0, 10.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = 0.5,
       append = False)
lorenz(ax=ax2, 
       state0 = [2.0, 5.0, -2.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = 0.5,
       append = False)
lorenz(ax=ax2, 
       state0 = [8.0, 10.0, 11.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = 0.5,
       append = False)
lorenz(ax=ax2, 
       state0 = [5.0, 8.0, 0.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = 0.5,
       append = False)
lorenz(ax=ax2, 
       state0 = [10.0, 6.0, 2.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = 0.5,
       append = False)

ax3 = fig.add_subplot(1, 2, 2, projection='3d')
lorenz(ax=ax3, t = np.arange(0.0, 1000, 0.01), r = 0.5, state0 = [10.0 + 0.00000001, 10.0, 10.0])
lorenz(ax=ax3, t = np.arange(0.0, 1000, 0.01), r = 0.5, line_color='r')
dist = 0
iter = 0

while(dist <= 1):
    
    if(iter >= 100000):
        break;
    
    dist = d(simulations[2][iter][0],
             simulations[2][iter][1],
             simulations[2][iter][2],
             simulations[3][iter][0],
             simulations[3][iter][1],
             simulations[3][iter][2],)
    iter += 1

fig.suptitle(f"Left, you can see that each point converges to same place and stays.\nOn the right, you can see the overlap between two simulations where one is slightly perturbed.\nMaximum distance between simulations is: {dist:.2e}.", size=18)
# Out:
# Text(0.5, 0.98, 'Left, you can see that each point converges to same place and stays.\nOn the right, you can see the overlap between two simulations where one is slightly perturbed.\nMaximum distance between simulations is: 7.20e-18.')

# %%
new_rho = 5

fig = plt.figure(figsize=(16, 8))

ax2 = fig.add_subplot(1, 2, 1, projection='3d')
lorenz(ax=ax2, 
       state0 = [10.0, 10.0, 10.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = new_rho,
       append = False)
lorenz(ax=ax2, 
       state0 = [2.0, 8.0, 10.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = new_rho,
       append = False)
lorenz(ax=ax2, 
       state0 = [2.0, 5.0, -2.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = new_rho,
       append = False)
lorenz(ax=ax2, 
       state0 = [8.0, 10.0, 11.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = new_rho,
       append = False)
lorenz(ax=ax2, 
       state0 = [5.0, 8.0, 0.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = new_rho,
       append = False)
lorenz(ax=ax2, 
       state0 = [10.0, 6.0, 2.0], 
       t = np.arange(0.0, 1000, 0.01), 
       r = new_rho,
       append = False)

ax3 = fig.add_subplot(1, 2, 2, projection='3d')
lorenz(ax=ax3, t = np.arange(0.0, 1000, 0.01), r = new_rho, state0 = [10.0 + 0.00000001, 10.0, 10.0])
lorenz(ax=ax3, t = np.arange(0.0, 1000, 0.01), r = new_rho, line_color='r')
dist = 0
iter = 0

while(dist <= 1):
    
    if(iter >= 100000):
        break;
    
    dist = d(simulations[2][iter][0],
             simulations[2][iter][1],
             simulations[2][iter][2],
             simulations[3][iter][0],
             simulations[3][iter][1],
             simulations[3][iter][2],)
    iter += 1

fig.suptitle(f"Left, you can see that each point converges to same place and stays.\nOn the right, you can see the overlap between two simulations where one is slightly perturbed.\nMaximum distance between simulations is: {dist:.2e}.", size=18)
# Out:
# Text(0.5, 0.98, 'Left, you can see that each point converges to same place and stays.\nOn the right, you can see the overlap between two simulations where one is slightly perturbed.\nMaximum distance between simulations is: 7.20e-18.')

# %%
fig = plt.figure(figsize=(16, 8))

ax2 = fig.add_subplot(1, 2, 1, projection='3d')
lorenz(ax=ax2, t = np.arange(0.0, 1000, 0.01), r = 10)
once=True

ax3 = fig.add_subplot(1, 2, 2, projection='3d')
lorenz(ax=ax3, t = np.arange(0.0, 1000, 0.01), r = 10, state0 = [10.0 + 0.00000001, 10.0, 10.0])
once=True
